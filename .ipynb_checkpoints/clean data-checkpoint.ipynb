# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"population2.csv")

# %%
df
# Out:
#         Country   Region      City  Population  Census_Year Census_Date  \
# 0        Canada    North  City_265         NaN         2017  19/12/2017
# 1        Canada     West  City_272    456999.0         2004  21/12/2004
# 2     Australia  Central  City_408    518184.0         2016  12/02/2016
# 3        Brazil     West  City_475   2257172.0         2012  14/08/2012
# 4       Germany  Central  City_177   3201381.0         2022  16/03/2022
# ...         ...      ...       ...         ...          ...         ...
# 9995  Australia     East  City_330   3631466.0         1997  08/04/1997
# 9996     Canada    South  City_459   2826346.0         2019  12/12/2019
# 9997      India  Central  City_403   4852977.0         2006  07/05/2006
# 9998     Canada    North  City_333   4111114.0         2019  16/04/2019
# 9999      India    South  City_309   3876888.0         2019  01/02/2019
#
#       Budget_USD  Actual_Spent_USD  Delay_Days Census_Status  Supervisor  \
# ...

# %%
df.describe()
# Out:
#          Population   Census_Year    Budget_USD  Actual_Spent_USD  \
# count  9.800000e+03  10000.000000  9.866000e+03      1.000000e+04
# mean   2.490913e+06   2009.082300  2.506657e+06      2.527763e+06
# std    1.427697e+06      7.760757  1.435275e+06      1.434785e+06
# min    1.436000e+03   1996.000000  1.005796e+04      1.711209e+04
# 25%    1.262348e+06   2002.000000  1.272117e+06      1.295107e+06
# 50%    2.492461e+06   2009.000000  2.513468e+06      2.538298e+06
# 75%    3.696279e+06   2016.000000  3.743077e+06      3.765873e+06
# max    4.999777e+06   2022.000000  4.999532e+06      5.043213e+06
#
#         Delay_Days  Households_Surveyed  Field_Workers  Data_Quality_Score
# count  6642.000000         10000.000000   10000.000000         8996.000000
# mean     46.391448          5011.593000      25.419200           74.869837
# std      59.098791          2922.681822      14.481652           14.386497
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              10000 non-null  object
#  1   Region               10000 non-null  object
#  2   City                 10000 non-null  object
#  3   Population           9800 non-null   float64
#  4   Census_Year          10000 non-null  int64
#  5   Census_Date          10000 non-null  object
#  6   Budget_USD           9866 non-null   float64
#  7   Actual_Spent_USD     10000 non-null  float64
#  8   Delay_Days           6642 non-null   float64
#  9   Census_Status        6757 non-null   object
#  10  Supervisor           6725 non-null   object
#  11  Households_Surveyed  10000 non-null  int64
#  12  Field_Workers        10000 non-null  int64
#  13  Data_Quality_Score   8996 non-null   float64
# dtypes: float64(5), int64(3), object(6)
# memory usage: 1.1+ MB

# %%
df["Population"]=df["Population"].fillna(0)

# %%
df
# Out:
#         Country   Region      City  Population  Census_Year Census_Date  \
# 0        Canada    North  City_265         0.0         2017  19/12/2017
# 1        Canada     West  City_272    456999.0         2004  21/12/2004
# 2     Australia  Central  City_408    518184.0         2016  12/02/2016
# 3        Brazil     West  City_475   2257172.0         2012  14/08/2012
# 4       Germany  Central  City_177   3201381.0         2022  16/03/2022
# ...         ...      ...       ...         ...          ...         ...
# 9995  Australia     East  City_330   3631466.0         1997  08/04/1997
# 9996     Canada    South  City_459   2826346.0         2019  12/12/2019
# 9997      India  Central  City_403   4852977.0         2006  07/05/2006
# 9998     Canada    North  City_333   4111114.0         2019  16/04/2019
# 9999      India    South  City_309   3876888.0         2019  01/02/2019
#
#       Budget_USD  Actual_Spent_USD  Delay_Days Census_Status  Supervisor  \
# ...

# %%
df["Data_Quality_Score"]=df["Data_Quality_Score"].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              10000 non-null  object
#  1   Region               10000 non-null  object
#  2   City                 10000 non-null  object
#  3   Population           10000 non-null  float64
#  4   Census_Year          10000 non-null  int64
#  5   Census_Date          10000 non-null  object
#  6   Budget_USD           9866 non-null   float64
#  7   Actual_Spent_USD     10000 non-null  float64
#  8   Delay_Days           6642 non-null   float64
#  9   Census_Status        6757 non-null   object
#  10  Supervisor           6725 non-null   object
#  11  Households_Surveyed  10000 non-null  int64
#  12  Field_Workers        10000 non-null  int64
#  13  Data_Quality_Score   10000 non-null  float64
# dtypes: float64(5), int64(3), object(6)
# memory usage: 1.1+ MB

# %%
df
# Out:
#         Country   Region      City  Population  Census_Year Census_Date  \
# 0        Canada    North  City_265         0.0         2017  19/12/2017
# 1        Canada     West  City_272    456999.0         2004  21/12/2004
# 2     Australia  Central  City_408    518184.0         2016  12/02/2016
# 3        Brazil     West  City_475   2257172.0         2012  14/08/2012
# 4       Germany  Central  City_177   3201381.0         2022  16/03/2022
# ...         ...      ...       ...         ...          ...         ...
# 9995  Australia     East  City_330   3631466.0         1997  08/04/1997
# 9996     Canada    South  City_459   2826346.0         2019  12/12/2019
# 9997      India  Central  City_403   4852977.0         2006  07/05/2006
# 9998     Canada    North  City_333   4111114.0         2019  16/04/2019
# 9999      India    South  City_309   3876888.0         2019  01/02/2019
#
#       Budget_USD  Actual_Spent_USD  Delay_Days Census_Status  Supervisor  \
# ...

# %%
df["Delay_Days"]=df["Delay_Days"].fillna(0)

# %%
df
# Out:
#         Country   Region      City  Population  Census_Year Census_Date  \
# 0        Canada    North  City_265         0.0         2017  19/12/2017
# 1        Canada     West  City_272    456999.0         2004  21/12/2004
# 2     Australia  Central  City_408    518184.0         2016  12/02/2016
# 3        Brazil     West  City_475   2257172.0         2012  14/08/2012
# 4       Germany  Central  City_177   3201381.0         2022  16/03/2022
# ...         ...      ...       ...         ...          ...         ...
# 9995  Australia     East  City_330   3631466.0         1997  08/04/1997
# 9996     Canada    South  City_459   2826346.0         2019  12/12/2019
# 9997      India  Central  City_403   4852977.0         2006  07/05/2006
# 9998     Canada    North  City_333   4111114.0         2019  16/04/2019
# 9999      India    South  City_309   3876888.0         2019  01/02/2019
#
#       Budget_USD  Actual_Spent_USD  Delay_Days Census_Status  Supervisor  \
# ...

# %%
df["Supervisor"]=df["Supervisor"].fillna("no name")

# %%
df
# Out:
#         Country   Region      City  Population  Census_Year Census_Date  \
# 0        Canada    North  City_265         0.0         2017  19/12/2017
# 1        Canada     West  City_272    456999.0         2004  21/12/2004
# 2     Australia  Central  City_408    518184.0         2016  12/02/2016
# 3        Brazil     West  City_475   2257172.0         2012  14/08/2012
# 4       Germany  Central  City_177   3201381.0         2022  16/03/2022
# ...         ...      ...       ...         ...          ...         ...
# 9995  Australia     East  City_330   3631466.0         1997  08/04/1997
# 9996     Canada    South  City_459   2826346.0         2019  12/12/2019
# 9997      India  Central  City_403   4852977.0         2006  07/05/2006
# 9998     Canada    North  City_333   4111114.0         2019  16/04/2019
# 9999      India    South  City_309   3876888.0         2019  01/02/2019
#
#       Budget_USD  Actual_Spent_USD  Delay_Days Census_Status  Supervisor  \
# ...

# %%
df["Budget_USD"]=df["Budget_USD"].fillna(0)

# %%
df
# Out:
#         Country   Region      City  Population  Census_Year Census_Date  \
# 0        Canada    North  City_265         0.0         2017  19/12/2017
# 1        Canada     West  City_272    456999.0         2004  21/12/2004
# 2     Australia  Central  City_408    518184.0         2016  12/02/2016
# 3        Brazil     West  City_475   2257172.0         2012  14/08/2012
# 4       Germany  Central  City_177   3201381.0         2022  16/03/2022
# ...         ...      ...       ...         ...          ...         ...
# 9995  Australia     East  City_330   3631466.0         1997  08/04/1997
# 9996     Canada    South  City_459   2826346.0         2019  12/12/2019
# 9997      India  Central  City_403   4852977.0         2006  07/05/2006
# 9998     Canada    North  City_333   4111114.0         2019  16/04/2019
# 9999      India    South  City_309   3876888.0         2019  01/02/2019
#
#       Budget_USD  Actual_Spent_USD  Delay_Days Census_Status  Supervisor  \
# ...

# %%
df["Census_Status"]=df["Census_Status"].replace(0,"available").fillna("not available")

# %%
df
# Out:
#         Country   Region      City  Population  Census_Year Census_Date  \
# 0        Canada    North  City_265         0.0         2017  19/12/2017
# 1        Canada     West  City_272    456999.0         2004  21/12/2004
# 2     Australia  Central  City_408    518184.0         2016  12/02/2016
# 3        Brazil     West  City_475   2257172.0         2012  14/08/2012
# 4       Germany  Central  City_177   3201381.0         2022  16/03/2022
# ...         ...      ...       ...         ...          ...         ...
# 9995  Australia     East  City_330   3631466.0         1997  08/04/1997
# 9996     Canada    South  City_459   2826346.0         2019  12/12/2019
# 9997      India  Central  City_403   4852977.0         2006  07/05/2006
# 9998     Canada    North  City_333   4111114.0         2019  16/04/2019
# 9999      India    South  City_309   3876888.0         2019  01/02/2019
#
#       Budget_USD  Actual_Spent_USD  Delay_Days  Census_Status  Supervisor  \
# ...

# %%
val = df["Actual_Spent_USD"].max()/6

# %%
bins=[0,val,val*2,val*3,val*4,val*5,val*6]
labels=[">1000k","100-500k","500-5m","1m-6m","5m-10m","10m"]

# %%
val*4
# Out:
# 3362141.953333333

# %%
df["cust_bucket"]=pd.cut(df["Actual_Spent_USD"],bins=bins, labels=labels, include_lowest=True)

# %%
df
# Out:
#         Country   Region      City  Population  Census_Year Census_Date  \
# 0        Canada    North  City_265         0.0         2017  19/12/2017
# 1        Canada     West  City_272    456999.0         2004  21/12/2004
# 2     Australia  Central  City_408    518184.0         2016  12/02/2016
# 3        Brazil     West  City_475   2257172.0         2012  14/08/2012
# 4       Germany  Central  City_177   3201381.0         2022  16/03/2022
# ...         ...      ...       ...         ...          ...         ...
# 9995  Australia     East  City_330   3631466.0         1997  08/04/1997
# 9996     Canada    South  City_459   2826346.0         2019  12/12/2019
# 9997      India  Central  City_403   4852977.0         2006  07/05/2006
# 9998     Canada    North  City_333   4111114.0         2019  16/04/2019
# 9999      India    South  City_309   3876888.0         2019  01/02/2019
#
#       Budget_USD  Actual_Spent_USD  Delay_Days  Census_Status  Supervisor  \
# ...

# %%
Actual_Spent_USD = df.groupby("cust_bucket", observed=True)["Actual_Spent_USD"].sum()

# %%
Actual_Spent_USD
# Out:
# cust_bucket
# >1000k      6.862919e+08
# 100-500k    2.149867e+09
# 500-5m      3.504252e+09
# 1m-6m       5.017026e+09
# 5m-10m      6.597766e+09
# 10m         7.322428e+09
# Name: Actual_Spent_USD, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.bar(labels, Actual_Spent_USD, color="skyblue")
plt.title("totall actual spent by cost bucket")
plt.xlabel("cost_bucket")
plt.ylabel("Actual_Spent_USD (USD)")
plt.xticks(rotation=45)
plt.grid(True, axis="y")
plt.tight_layout()
plt.show()
